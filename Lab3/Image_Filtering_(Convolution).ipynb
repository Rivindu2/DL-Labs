# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the image using OpenCV

# %%
im = cv2.imread('/Users/rivindu/Desktop/Lab_3/lenna.png') #change the path as needed

# %%
im.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ### Convert the RGB image into a grayscale image

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im.shape
# Out:
# (512, 512)

# %% [markdown]
# ### Define vertical and horizontal filter kernels

# %%
v_kernel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
])

# %%
h_kernel = np.array([
    [-1, -1, -1],
    [0, 0, 0],
    [1, 1, 1]
])

d_kernel = np.array([    
[ 0  ,1 ,1],
[-1 , 0, 1],
[-1 ,-1 ,0 ],
])

e_kernal= np.array([    
[0, 0, -1],
    [0, 1, 0],
    [0, 0, 0]

])

# %% [markdown]
# ### Do the filtering

# %%
v_image = cv2.filter2D(im, -1, v_kernel)
h_image = cv2.filter2D(im, -1, h_kernel)
d_45_image = cv2.filter2D(im, -1, d_45_kernel)
e_image = cv2.filter2D(im, -1, e_kernal)

# %% [markdown]
# ### Display results

# %%
plt.imshow(im, cmap='gray')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='gray')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='gray')
plt.title('Horizontal Image')

plt.figure()
plt.imshow(d_45_image, cmap='gray')
plt.title('45deg diagonal Image')

plt.figure()
plt.imshow(e_image, cmap='gray')
plt.title('100deg diag Image')
# Out:
# Text(0.5, 1.0, '100deg diag Image')
